# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load and prepare data

# %% [markdown]
# Load the data

# %%
df=pd.read_csv('https://covidtracking.com/api/v1/states/daily.csv')

# %% [markdown]
# Reverse the order of the data, some plottings will go better if the oldest dates are on top of the dataframe.

# %%
df=df.iloc[::-1]

# %% [markdown]
# Also, stripping out the year and turning the date into a string will simplify plotting.

# %%
df['Date']=df['date'].astype(str).str[5:]
df['DateTime']=pd.to_datetime(df['date'], format='%Y%m%d')

# %% [markdown]
# # Question 1:  How many states?

# %% [markdown]
# How many different "states" are there?

# %%
#print(np.unique(df['state']))
print('There are %d unique state entries, must be including territories.'%len(np.unique(df['state'])))
# Out:
# There are 56 unique state entries, must be including territories.

# %% [markdown]
# # Question 2: Which 5 states have highest positive testing rate?

# %% [markdown]
# First we will make a new dataframe that has just the states, positives, negatives, and the positive fraction.

# %%
possneg = df.pivot_table(index='state', aggfunc=np.max, values=['positive', 'negative'])
possneg
# Out:
#          negative  positive
# state
# AK       609898.0   17860.0
# AL      1203497.0  197777.0
# AR      1273985.0  115812.0
# AS         1768.0       0.0
# AZ      1567864.0  250633.0
# CA     18241002.0  940010.0
# CO      1152436.0  114709.0
# CT      2326504.0   75373.0
# DC       519490.0   17601.0
# DE       331130.0   25534.0
# FL      5436911.0  810256.0
# GA      3280826.0  366452.0
# GU        64853.0    4903.0
# HI       295153.0   15531.0
# IA       781314.0  126740.0
# ID       334750.0   67024.0
# IL      7593157.0  443815.0
# IN      1556732.0  191764.0
# KS       571465.0   92215.0
# KY      1886645.0  113009.0
# LA      2635755.0  190164.0
# MA      2649240.0  163299.0
# MD      1830301.0  148766.0
# ME       650173.0    7077.0
# MI      4881516.0  212160.0
# MN      1759542.0  160923.0
# MO      1353932.0  193023.0
# MP        15993.0      96.0
# MS       837208.0  122275.0
# MT       481333.0   35955.0
# NC      3901456.0  282802.0
# ND       252788.0   48301.0
# NE       529830.0   74060.0
# NH       339573.0   11563.0
# NJ      4523834.0  245257.0
# NM      1153107.0   49240.0
# NV       719450.0  104093.0
# NY     14518342.0  515815.0
# OH      4414207.0  230209.0
# OK      1529345.0  127772.0
# OR       835905.0   47049.0
# PA      2374265.0  217666.0
# PR       305972.0   69020.0
# RI       411899.0   35122.0
# SC      1685018.0  180870.0
# SD       217005.0   49791.0
# TN      3490582.0  269802.0
# TX      7477787.0  926400.0
# UT       990501.0  121485.0
# VA      2529339.0  185836.0
# VI        23358.0    1388.0
# VT       188820.0    2267.0
# WA      2385140.0  110011.0
# WI      1872295.0  257287.0
# WV       780221.0   25987.0
# WY       120717.0   15044.0

# %%
posneg=df.groupby(['state']).aggregate({'positive':np.max, 'negative':np.max}).reset_index()
posneg['PositiveRatio']=posneg['positive']/(posneg['positive']+posneg['negative'])
posneg.head()
# Out:
#   state  positive   negative  PositiveRatio
# 0    AK   17860.0   609898.0       0.028450
# 1    AL  197777.0  1203497.0       0.141141
# 2    AR  115812.0  1273985.0       0.083330
# 3    AS       0.0     1768.0       0.000000
# 4    AZ  250633.0  1567864.0       0.137824

# %% [markdown]
# Now find the 5 highest ratios.

# %%
posneg.sort_values(by='PositiveRatio', ascending=False)[0:5][['state', 'PositiveRatio']]
# Out:
#    state  PositiveRatio
# 45    SD       0.186626
# 42    PR       0.184057
# 15    ID       0.166820
# 31    ND       0.160421
# 1     AL       0.141141

# %% [markdown]
# # Question 3:  Plot daily death toll for whole country

# %% [markdown]
# Let's plot daily death toll for the whole country.

# %%
plt.figure(figsize=[15,8])
combined_df = df.pivot_table(index='DateTime', values='deathIncrease', aggfunc=np.sum).reset_index()
sns.lineplot(data=combined_df, x='DateTime', y='deathIncrease')
plt.title('US Daily Death Toll')
# Out:
# Text(0.5, 1.0, 'US Daily Death Toll')

# %%
from scipy.interpolate import interp1d

# %%
import scipy.signal
plt.figure(figsize=[15,8])
combined_df = df.pivot_table(index='DateTime', values='deathIncrease', aggfunc=np.sum).reset_index()
combined_df['Smoothed'] = scipy.signal.savgol_filter(combined_df['deathIncrease'], window_length=7, polyorder=1)
sns.lineplot(data=combined_df, x='DateTime', y='Smoothed')
plt.title('US Daily Death Toll')
# Out:
# Text(0.5, 1.0, 'US Daily Death Toll')

# %% [markdown]
# # Question 4:  Plot daily death toll for just Kansas and Missouri

# %% [markdown]
# Now let's focus on Missouri and Kansas, first we will graph their combined totals.

# %%
plt.figure(figsize=[15,8])
combined_df = df[df['state'].isin(['MO', 'KS'])].pivot_table(values='deathIncrease', 
                                                            aggfunc=np.sum, index='DateTime').reset_index()
combined_df['Smoothed'] = scipy.signal.savgol_filter(combined_df['deathIncrease'], window_length=13, polyorder=1)
sns.lineplot(data=combined_df, x='DateTime', y='Smoothed')
plt.title('Missouri + Kansas Daily Death Toll')
# Out:
# Text(0.5, 1.0, 'Missouri + Kansas Daily Death Toll')

# %% [markdown]
# Now let's separate them out.

# %% [markdown]
# # Question 5:  Plot the daily testing rate for Kansas and Missouri

# %% [markdown]
# What is the daily testing rate looking like for Kansas and Missouri?

# %%
plt.figure(figsize=[15,8])
sns.lineplot(data=df[df['state'].isin(['MO', 'KS'])], x='DateTime', y='totalTestResultsIncrease', hue='state')
plt.title('Missouri + Kansas Daily Testings')
# Out:
# Text(0.5, 1.0, 'Missouri + Kansas Daily Testings')

# %%
plt.figure(figsize=[15,8])
df.loc[df['state']=='MO','Smoothed'] = scipy.signal.savgol_filter(df.loc[df['state']=='MO']['deathIncrease'], window_length=13, polyorder=1)
df.loc[df['state']=='KS','Smoothed'] = scipy.signal.savgol_filter(df.loc[df['state']=='KS']['deathIncrease'], window_length=13, polyorder=1)
sns.lineplot(data=df[df['state'].isin(['MO', 'KS'])], x='DateTime', y='Smoothed', hue='state')
plt.title('Missouri and Kansas Daily Death Toll')
# Out:
# Text(0.5, 1.0, 'Missouri and Kansas Daily Death Toll')

# %% [markdown]
# # Question 6:  What is the peak death day for the whole country?

# %%
agged_df = df.pivot_table(index='DateTime', values='deathIncrease', aggfunc=np.sum).reset_index()
agged_df.iloc[np.argmax(agged_df['deathIncrease'])]
# Out:
# DateTime         2020-05-07 00:00:00
# deathIncrease                   2752
# Name: 106, dtype: object

# %% [markdown]
# So far it is May 7, on which 2752 died.

# %% [markdown]
# # Challenge 1:  Make a table of peak testing day for each state

# %% [markdown]
# This way uses lambda, groupby, and apply, 3 functions we have not used in the class.

# %%
df.groupby(['state']).apply(lambda x: x.iloc[np.argmax(x['totalTestResultsIncrease'])]).sort_values(by='DateTime')[['totalTestResultsIncrease','DateTime']]
# Out:
#        totalTestResultsIncrease   DateTime
# state
# ID                         8188 2020-04-29
# NJ                       113486 2020-05-11
# TN                        54879 2020-06-12
# AS                          522 2020-06-25
# PR                        79467 2020-06-29
# MP                         2547 2020-07-08
# AL                        23846 2020-07-10
# NV                        14654 2020-07-11
# FL                       129145 2020-07-12
# VI                          768 2020-07-17
# IA                        11762 2020-07-19
# GA                        45506 2020-07-24
# OK                        42667 2020-07-25
# LA                        55947 2020-08-04
# MD                        40672 2020-08-09
# SC                        45756 2020-08-14
# KS                        20642 2020-08-24
# NM                        14138 2020-08-24
# MT                        22924 2020-08-24
# VA                        36769 2020-08-28
# AK                        25625 2020-09-01
# IL                       149499 2020-09-04
# HI                        10725 2020-09-06
# AZ                        23844 2020-09-17
# MS                        69454 2020-09-19
# KY                       148313 2020-09-23
# OR                        12408 2020-09-25
# TX                       154848 2020-09-28
# AR                        57071 2020-09-28
# OH                        74262 2020-10-01
# PA                        28915 2020-10-04
# SD                         7303 2020-10-07
# NE                        19440 2020-10-10
# DE                         8353 2020-10-11
# CT                       100405 2020-10-12
# ME                        23140 2020-10-13
# WA                        62470 2020-10-13
# MO                       130675 2020-10-14
# WY                         5363 2020-10-15
# MN                        43703 2020-10-16
# RI                        25384 2020-10-17
# NH                        15272 2020-10-18
# VT                         9007 2020-10-23
# WV                        13169 2020-10-26
# CA                       194944 2020-10-26
# NY                       168353 2020-10-29
# ND                        11315 2020-10-30
# UT                        15541 2020-10-30
# WI                        53451 2020-10-31
# IN                        46698 2020-10-31
# NC                        49365 2020-10-31
# DC                        11116 2020-11-01
# CO                        41137 2020-11-01
# MI                        96707 2020-11-02
# GU                         1364 2020-11-03
# MA                       103066 2020-11-04

# %% [markdown]
# This way uses only things we have covered in class.

# %%
fff = df.sort_values(by='totalTestResultsIncrease', ascending=False)[['state', 'totalTestResultsIncrease', 'DateTime']]
asd, arrs = np.unique(fff['state'], return_index=True)
fff.iloc[arrs]
# Out:
#       state  totalTestResultsIncrease   DateTime
# 3584     AK                     25625 2020-09-01
# 6553     AL                     23846 2020-07-10
# 2074     AR                     57071 2020-09-28
# 7395     AS                       522 2020-06-25
# 2692     AZ                     23844 2020-09-17
# 509      CA                    194944 2020-10-26
# 174      CO                     41137 2020-11-01
# 1295     CT                    100405 2020-10-12
# 176      DC                     11116 2020-11-01
# 1353     DE                      8353 2020-10-11
# 6450     FL                    129145 2020-07-12
# 5779     GA                     45506 2020-07-24
# 68       GU                      1364 2020-11-03
# 3317     HI                     10725 2020-09-06
# 6062     IA                     11762 2020-07-19
# 10599    ID                      8188 2020-04-29
# 3432     IL                    149499 2020-09-04
# 241      IN                     46698 2020-10-31
# 4050     KS                     20642 2020-08-24
# 2371     KY                    148313 2020-09-23
# 5172     LA                     55947 2020-08-04
# 21       MA                    103066 2020-11-04
# 4894     MD                     40672 2020-08-09
# 1255     ME                     23140 2020-10-13
# 136      MI                     96707 2020-11-02
# 1089     MN                     43703 2020-10-16
# 1202     MO                    130675 2020-10-14
# 6691     MP                      2547 2020-07-08
# 2604     MS                     69454 2020-09-19
# 4061     MT                     22924 2020-08-24
# 254      NC                     49365 2020-10-31
# 311      ND                     11315 2020-10-30
# 1432     NE                     19440 2020-10-10
# 985      NH                     15272 2020-10-18
# 9946     NJ                    113486 2020-05-11
# 4067     NM                     14138 2020-08-24
# 6532     NV                     14654 2020-07-11
# 373      NY                    168353 2020-10-29
# 1942     OH                     74262 2020-10-01
# 5751     OK                     42667 2020-07-25
# 2280     OR                     12408 2020-09-25
# 1777     PA                     28915 2020-10-04
# 7210     PR                     79467 2020-06-29
# 1051     RI                     25384 2020-10-17
# 4636     SC                     45756 2020-08-14
# 1613     SD                      7303 2020-10-07
# 8166     TN                     54879 2020-06-12
# 2119     TX                    154848 2020-09-28
# 328      UT                     15541 2020-10-30
# 3857     VA                     36769 2020-08-28
# 6210     VI                       768 2020-07-17
# 723      VT                      9007 2020-10-23
# 1284     WA                     62470 2020-10-13
# 277      WI                     53451 2020-10-31
# 558      WV                     13169 2020-10-26
# 1175     WY                      5363 2020-10-15

# %% [markdown]
# # Challenge 2:  Plot the per capita testing fraction in descending order

# %% [markdown]
# First let's make a new dataframe that simply aggregates the total tests per state.

# %%
tests_agged=df.groupby(['state']).agg({'totalTestResultsIncrease':np.sum}).reset_index()

# %% [markdown]
# Now let's read in the population data, and keep only the parts we want.

# %%
pop=pd.read_csv('http://www2.census.gov/programs-surveys/popest/datasets/2010-2019/national/totals/nst-est2019-alldata.csv', usecols=['NAME', 'CENSUS2010POP'])

# %% [markdown]
# Now the problem is that our tests_agged has state abbreviations and our pop dataframe has full state names.  We need to convert one to the other before we can merge.

# %% [markdown]
# First let's load a file that has both.

# %%
abb=pd.read_csv('http://www.fonz.net/blog/wp-content/uploads/2008/04/states.csv')

# %% [markdown]
# Then we will make a dictionary that takes abbreviations and turns them into the full state names.

# %%
mapper={a:b for a,b in zip(abb['Abbreviation'], abb['State'])}

# %% [markdown]
# Now that we have a dictionary, we can create a new column in tests_agged and use .map to generate it.

# %%
tests_agged['StateNames']=tests_agged['state'].map(mapper)

# %% [markdown]
# Now we can merge the tests_agged and pop dataframes because they both have a column with the full state name in them.

# %%
tests_agged=tests_agged.merge(pop, left_on='StateNames', right_on='NAME')

# %% [markdown]
# Calculate the per 1000 tests, add to a column

# %%
tests_agged['PerThousand']=tests_agged['totalTestResultsIncrease']/tests_agged['CENSUS2010POP']*1000

# %% [markdown]
# Sort, show the top 5.

# %%
tests_agged.sort_values(by='PerThousand', ascending=False)[0:5].loc[:,['NAME', 'PerThousand']]
# Out:
#                     NAME  PerThousand
# 28          North Dakota  1285.072206
# 39          Rhode Island  1125.210082
# 19         Massachusetts   973.627400
# 7   District of Columbia   892.578479
# 0                 Alaska   883.867361

# %%
plt.figure(figsize=[15,15])
sns.barplot(data=tests_agged.sort_values(by='PerThousand', ascending=False), x='PerThousand', y='NAME')
# Out:
# <AxesSubplot:xlabel='PerThousand', ylabel='NAME'>
